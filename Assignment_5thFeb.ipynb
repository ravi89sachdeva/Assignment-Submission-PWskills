# %%
## Explain class and object wrt object oriented programming. Give a suitable example

Ans- A class is a user defined layout or blueprint of an object that describes what a specific kind of object 
will look like. A class description consists of two things- one is attributes or member variables , other is 
implementation of behaviour or member functions. 
Example:- A mobile phone has attributes like brand name , RAM and functions like texting and calling. 
So, mobile phone is a class of various phones (the objects).

An object is a single instance of class which contains data and methods working on that data.So an object
consists of three things : name or variable name , member data that describes the object and member methods as 
behaviour of an object.
Example-Samsung galaxy is an object with brand name Samsung , 2GB RAM as properties and texting as behaviours.

# %%
## Name the four pillars of OOPs.

Ans- Inheritance, Polymorphism, Encapsulation and Abstraction.

# %%
## Explain why the __init__ function is used . Give a suitable example.

Ans-__init__ function lets the class initialize the object's attributes and serves no other purpose.
It is only used within classes.

Example: 
    class bank:
        def __init__(self):
            print('This is init call')

cust1=Bank() 
## the moment we declare an object , __init__ is called .

# %%
## why self is used in OOPs.

Ans- It is used to represen the instance/ variable/ object of a class . It works as a reference to the object.
By using self , we can access the attributes and methods of the class in python.

# %%
## What is inheritence . Give an example of each type of inheritence.

Ans-Inheritence is a mechanism in which once class acquires the property of another class

1. Single inheritence- This is a form of inheritance in which a class inherits only one parent class.
Example-
class Parent:
  def f1(self):
    print("Function of parent class.")

class Child(Parent):
  def f2(self):
    print("Function of child class.")

object1 = Child()
object1.f1()
object1.f2()
Here the class Child is inheriting only one class Parent

2. Multiple Inheritance-An inheritance becomes multiple inheritances when a class inherits more than one parent class
Example-
class Parent_1:
  def f1(self):
    print("Function of parent_1 class.")

class Parent_2:
  def f2(self):
    print("Function of parent_2 class.")

class Parent_3:
  def f3(self):
    print("function of parent_3 class.")

class Child(Parent_1, Parent_2, Parent_3):
  def f4(self):
    print("Function of child class.")

object_1 = Child()
object_1.f1()
object_1.f2()
object_1.f3()
object_1.f4()
Here we have one Child class which is inheriting properties of three-parent classes Parent_1, Parent_2, and Parent_3. 
All the classes have different functions and all of the functions are called using the object of the Child class.

3. Multi-level Inheritance
For example, a class_1 is inherited by a class_2 and 
this class_2 also gets inherited by class_3 and this process goes on. This is known as multi-level inheritance
class Parent:
  def f1(self):
    print("Function of parent class.")

class Child_1(Parent):
  def f2(self):
    print("Function of child_1 class.")

class Child_2(Child_1):
  def f3(self):
    print("Function of child_2 class.")

obj_1 = Child_1()
obj_2 = Child_2()

obj_1.f1()
obj_1.f2()

print("\n")
obj_2.f1()
obj_2.f2()
obj_2.f3()

4. Hierarchical inheritance
In this, various Child classes inherit a single Parent class.
class Parent:
deff1(self):
print("Function of parent class.")

class Child_1(Parent):
deff2(self):
print("Function of child_1 class.")

class Child_2(Parent):
deff3(self):
print("Function of child_2 class.")

obj_1 = Child_1()
obj_2 = Child_2()

obj_1.f1()
obj_1.f2()

print('\n')
obj_2.f1()
obj_2.f3()

5. Hybrid Inheritance
When there is a combination of more than one form of inheritance, it is known as hybrid inheritance
class Parent:
  def f1(self):
    print("Function of parent class.")

class Child_1(Parent):
  def f2(self):
    print("Function of child_1 class.")

class Child_2(Parent):
  def f3(self):
    print("Function of child_2 class.")

class Child_3(Child_1, Child_2):
  def f4(self):
    print("Function of child_3 class.")

obj = Child_3()
obj.f1()
obj.f2()
obj.f3()
obj.f4()

In this example, two classes ‘Child_1′ and ‘Child_2’ are derived from base class ‘Parent’ using hierarchical inheritance. Another class ‘Child_3’ is derived from classes ‘Child_1’ and ‘Child_2’ using multiple inheritances. 
The class ‘Child_3’ is now derived using hybrid inheritance
